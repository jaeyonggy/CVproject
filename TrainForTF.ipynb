# %%
import os
import shutil
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ZINDI-image/csv_files/Train.csv')  # train set
df
# Out:
#                   Image_id  Label
# 0     id_02amazy34fgh2.jpg      1
# 1     id_02mh3w48pmyc9.jpg      0
# 2     id_02rpb463h9d3w.jpg      0
# 3     id_02wc3jeeao8ol.jpg      1
# 4     id_03t2hapb8wz8p.jpg      1
# ...                    ...    ...
# 1614  id_ztf4l3e8m6gmh.jpg      0
# 1615  id_ztgztu5vexsoe.jpg      1
# 1616  id_ztue0lrjt4l4g.jpg      0
# 1617  id_zyubro5pfg31d.jpg      0
# 1618  id_zz20l1nlkrid7.jpg      0
#
# [1619 rows x 2 columns]

# %%
# traverse whole directory
for root, dirs, files in os.walk('/content/drive/MyDrive/ZINDI-image/train/'):
    # select file name
    for file in files:
        if df[df['Image_id']==file].iloc[0]['Label'] == 0:
          shutil.copy(root+file, '/content/drive/MyDrive/ZINDI-image/train_TF/0/'+file)
        else:
          shutil.copy(root+file, '/content/drive/MyDrive/ZINDI-image/train_TF/1/'+file)

# %%
count = 0

for root, dirs, files in os.walk('/content/drive/MyDrive/ZINDI-image/train_TF/0'):
    # select file name
    for file in files:
        if file.endswith('.jpg'):
            count += 1

count
# Out:
# 810

# %%
count = 0

for root, dirs, files in os.walk('/content/drive/MyDrive/ZINDI-image/train_TF/1'):
    # select file name
    for file in files:
        if file.endswith('.jpg'):
            count += 1

count
# Out:
# 809
