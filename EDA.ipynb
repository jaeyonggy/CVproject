# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ZINDI-image/csv_files/Train.csv')

# %%
df.groupby('Label').count()
# Out:
#        Image_id
# Label
# 0           810
# 1           809

# %%
df['Image_id']  # It's in alphanumeric order
# Out:
# 0       id_02amazy34fgh2.jpg
# 1       id_02mh3w48pmyc9.jpg
# 2       id_02rpb463h9d3w.jpg
# 3       id_02wc3jeeao8ol.jpg
# 4       id_03t2hapb8wz8p.jpg
#                 ...
# 1614    id_ztf4l3e8m6gmh.jpg
# 1615    id_ztgztu5vexsoe.jpg
# 1616    id_ztue0lrjt4l4g.jpg
# 1617    id_zyubro5pfg31d.jpg
# 1618    id_zz20l1nlkrid7.jpg
# Name: Image_id, Length: 1619, dtype: object
